# %%
[This is a link to the dataset](https://www.kaggle.com/datasets/surajjha101/stores-area-and-sales-data?resource=download)
# Out:
#   File "<ipython-input-4-a11cf61c58be>", line 1
#     [This is a link to the dataset](https://repository.upenn.edu/mead/28/)
#                   ^
# SyntaxError: invalid syntax

# %%
Store ID: (Index) ID of the particular store.

Store_Area: Physical Area of the store in yard square.

Items_Available: Number of different items available in the corresponding store.

DailyCustomerCount: Number of customers who visited to stores on an average over month.

Store_Sales: Sales in (US $) that stores made.

# %%
# import data
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('Stores.csv')
df
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0            1        1659             1961                   530        66490
# 1            2        1461             1752                   210        39820
# 2            3        1340             1609                   720        54010
# 3            4        1451             1748                   620        53730
# 4            5        1770             2111                   450        46620
# 5            6        1442             1733                   760        45260
# 6            7        1542             1858                  1030        72240
# 7            8        1261             1507                  1020        37720
# 8            9        1090             1321                   680        46310
# 9           10        1030             1235                  1130        44150
# 10          11        1187             1439                  1090        71280
# ...

# %%
# what's the data look like?
df.head(2)
# Out:
#               name   start     end          street      city state country
# 0         Shaw, S.     NaN     NaN             NaN  Waterloo    NY     USA
# 1  Davies and Kent  1861.0  1862.0  113 Nassau St.  New York    NY     USA

# %%
df.tail(2)
# Out:
#                         name   start     end        street      city state  \
# 5960  McLoughlin Bros., Inc.  1886.0  1892.0  623 Broadway  New York    NY
# 5961  McLoughlin Bros., Inc.  1892.0  1898.0  874 Broadway  New York    NY
#
#      country
# 5960     NaN
# 5961     NaN

# %%
df.sample()
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 117        118        1712             2046                   460        31180

# %%
df.shape
# Out:
# (5962, 7)

# %%
df.columns
# Out:
# Index(['name', 'start', 'end', 'street', 'city', 'state', 'country'], dtype='object')

# %%
df.describe()
# Out:
#               start           end
# count  5.286000e+03  5.286000e+03
# mean   7.181425e+04  7.180866e+04
# std    3.596247e+06  3.596247e+06
# min    1.000000e+00  2.000000e+00
# 25%    1.835000e+03  1.836000e+03
# 50%    1.848000e+03  1.851000e+03
# 75%    1.860000e+03  1.864000e+03
# max    1.855019e+08  1.855019e+08

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Data columns (total 5 columns):
# Store ID                896 non-null int64
# Store_Area              896 non-null int64
# Items_Available         896 non-null int64
# Daily_Customer_Count    896 non-null int64
# Store_Sales             896 non-null int64
# dtypes: int64(5)
# memory usage: 35.1 KB

# %%
# check if there are any null values
df.isna()
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0        False       False            False                 False        False
# 1        False       False            False                 False        False
# 2        False       False            False                 False        False
# 3        False       False            False                 False        False
# 4        False       False            False                 False        False
# 5        False       False            False                 False        False
# 6        False       False            False                 False        False
# 7        False       False            False                 False        False
# 8        False       False            False                 False        False
# 9        False       False            False                 False        False
# 10       False       False            False                 False        False
# ...

# %%
df.isna().sum()
# Out:
# Store ID                0
# Store_Area              0
# Items_Available         0
# Daily_Customer_Count    0
# Store_Sales             0
# dtype: int64

# %%
#  data type
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# plots of features
df['Store_Area'].plot()

# %%
df['Items_Available'].plot()

# %%
df['Daily_Customer_Count'].plot()

# %%
df['Store_Sales'].plot()

# %%
# plots of several pairs of features
x=df['Daily_Customer_Count']
y=df['Store_Sales']
plt.scatter(x,y)

# %%
x1=df['Items_Available']
y1=df['Daily_Customer_Count']
plt.scatter(x1,y1)

# %%
# Out:
# Store ID                int64
# Store_Area              int64
# Items_Available         int64
# Daily_Customer_Count    int64
# Store_Sales             int64
# dtype: object

# %%
#pre-processing
There is not missing values and the data types are appropriate.If we want to do further analysis like regression, we may need to delete extreme values which may have an impact on our result.
# 3 quesions
Is there is a relationship bwetween Store_Area and Daily_Customer_Count?
Is there is a relationship between Store_Area and Daily_Customer_Count?
The above scatter plots show that there are not clear relationships between the 2 pairs of features. Is that true？
